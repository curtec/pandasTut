# %%
import pandas as pd
import sys
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sys.version
# Out:
# '3.11.3 (tags/v3.11.3:f3909b8, Apr  4 2023, 23:49:59) [MSC v.1934 64 bit (AMD64)]'

# %%
'pandas version', pd.__version__
# Out:
# ('pandas version', '2.2.0')

# %% [markdown]
# # The Basics

# %% [markdown]
# Create dataframe from raw data

# %%
data = {
    'Make': ['Holden', 'Ford', 'Datsun'],
    'Model': ['Kingswood', 'Falcon', '120y'],
    'Year': [1970, 1969, 1972]
}

df = pd.DataFrame(data)

df
# Out:
#      Make      Model  Year
# 0  Holden  Kingswood  1970
# 1    Ford     Falcon  1969
# 2  Datsun       120y  1972

# %% [markdown]
# Reading in a file

# %%
df1 = pd.read_csv('world_population.csv')
df = pd.read_parquet("Combined_Flights_2022.parquet")
df
# Out:
#        FlightDate                                    Airline Origin Dest  \
# 0      2022-04-04  Commutair Aka Champlain Enterprises, Inc.    GJT  DEN
# 1      2022-04-04  Commutair Aka Champlain Enterprises, Inc.    HRL  IAH
# 2      2022-04-04  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
# 3      2022-04-04  Commutair Aka Champlain Enterprises, Inc.    IAH  GPT
# 4      2022-04-04  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
# ...           ...                                        ...    ...  ...
# 590537 2022-03-31                          Republic Airlines    MSY  EWR
# 590538 2022-03-17                          Republic Airlines    CLT  EWR
# 590539 2022-03-08                          Republic Airlines    ALB  ORD
# 590540 2022-03-25                          Republic Airlines    EWR  PIT
# 590541 2022-03-07                          Republic Airlines    EWR  RDU
#
#         Cancelled  Diverted  CRSDepTime  DepTime  DepDelayMinutes  DepDelay  \
# ...

# %%
df.head()
# Out:
#   FlightDate                                    Airline Origin Dest  \
# 0 2022-04-04  Commutair Aka Champlain Enterprises, Inc.    GJT  DEN
# 1 2022-04-04  Commutair Aka Champlain Enterprises, Inc.    HRL  IAH
# 2 2022-04-04  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
# 3 2022-04-04  Commutair Aka Champlain Enterprises, Inc.    IAH  GPT
# 4 2022-04-04  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
#
#    Cancelled  Diverted  CRSDepTime  DepTime  DepDelayMinutes  DepDelay  ...  \
# 0      False     False        1133   1123.0              0.0     -10.0  ...
# 1      False     False         732    728.0              0.0      -4.0  ...
# 2      False     False        1529   1514.0              0.0     -15.0  ...
# 3      False     False        1435   1430.0              0.0      -5.0  ...
# 4      False     False        1135   1135.0              0.0       0.0  ...
#
#    WheelsOff  WheelsOn  TaxiIn  CRSArrTime  ArrDelay  ArrDel15  \
# ...

# %% [markdown]
# In the cell above some of the columns were hidden to save room but you can set the max number of columns as below.

# %%
pd.set_option('display.max_columns', 61)
df.head()
# Out:
#   FlightDate                                    Airline Origin Dest  \
# 0 2022-04-04  Commutair Aka Champlain Enterprises, Inc.    GJT  DEN
# 1 2022-04-04  Commutair Aka Champlain Enterprises, Inc.    HRL  IAH
# 2 2022-04-04  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
# 3 2022-04-04  Commutair Aka Champlain Enterprises, Inc.    IAH  GPT
# 4 2022-04-04  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
#
#    Cancelled  Diverted  CRSDepTime  DepTime  DepDelayMinutes  DepDelay  \
# 0      False     False        1133   1123.0              0.0     -10.0
# 1      False     False         732    728.0              0.0      -4.0
# 2      False     False        1529   1514.0              0.0     -15.0
# 3      False     False        1435   1430.0              0.0      -5.0
# 4      False     False        1135   1135.0              0.0       0.0
#
#    ArrTime  ArrDelayMinutes  AirTime  CRSElapsedTime  ActualElapsedTime  \
# ...

# %%
# pull a random subset of rows 
df.sample(8)
# Out:
#        FlightDate                 Airline Origin Dest  Cancelled  Diverted  \
# 527902 2022-06-27  American Airlines Inc.    CLT  BDL      False     False
# 34955  2022-05-22   SkyWest Airlines Inc.    PHX  BOI      False     False
# 503321 2022-07-11  Southwest Airlines Co.    DEN  SAT      False     False
# 270260 2022-01-24       Republic Airlines    BOS  LGA      False     False
# 22852  2022-01-03    Delta Air Lines Inc.    ATL  SAV      False     False
# 438646 2022-07-07         JetBlue Airways    ORH  FLL      False     False
# 215423 2022-06-21    Delta Air Lines Inc.    SLC  DEN      False     False
# 390294 2022-03-12   United Air Lines Inc.    DEN  TPA      False     False
#
#         CRSDepTime  DepTime  DepDelayMinutes  DepDelay  ArrTime  \
# 527902        1635   1800.0             85.0      85.0   2055.0
# 34955         1320   1314.0              0.0      -6.0   1620.0
# 503321        1555   1557.0              2.0       2.0   1852.0
# ...

# %%
# to use fraction to get a fraction of the data set (add random_state= if you want the results to be reproducable)
df.sample(frac=0.1, random_state=200)
# Out:
#        FlightDate                 Airline Origin Dest  Cancelled  Diverted  \
# 99509  2022-06-05   United Air Lines Inc.    FLL  IAH      False     False
# 144842 2022-02-18       Endeavor Air Inc.    ORF  LGA      False     False
# 479872 2022-05-28  Southwest Airlines Co.    HOU  CMH      False     False
# 399817 2022-04-12               Envoy Air    DFW  ACT      False     False
# 302111 2022-04-14    Delta Air Lines Inc.    SEA  LAS      False     False
# ...           ...                     ...    ...  ...        ...       ...
# 158899 2022-01-27             Horizon Air    OAK  SEA      False     False
# 323853 2022-03-19   SkyWest Airlines Inc.    XNA  ORD      False     False
# 330399 2022-02-25  Frontier Airlines Inc.    MCO  ISP      False     False
# 476558 2022-05-27  Southwest Airlines Co.    FLL  TPA      False     False
# 413151 2022-02-26      Mesa Airlines Inc.    FSD  DFW      False     False
#
#         CRSDepTime  DepTime  DepDelayMinutes  DepDelay  ArrTime  \
# ...

# %%
df.columns
# Out:
# Index(['FlightDate', 'Airline', 'Origin', 'Dest', 'Cancelled', 'Diverted',
#        'CRSDepTime', 'DepTime', 'DepDelayMinutes', 'DepDelay', 'ArrTime',
#        'ArrDelayMinutes', 'AirTime', 'CRSElapsedTime', 'ActualElapsedTime',
#        'Distance', 'Year', 'Quarter', 'Month', 'DayofMonth', 'DayOfWeek',
#        'Marketing_Airline_Network', 'Operated_or_Branded_Code_Share_Partners',
#        'DOT_ID_Marketing_Airline', 'IATA_Code_Marketing_Airline',
#        'Flight_Number_Marketing_Airline', 'Operating_Airline',
#        'DOT_ID_Operating_Airline', 'IATA_Code_Operating_Airline',
#        'Tail_Number', 'Flight_Number_Operating_Airline', 'OriginAirportID',
#        'OriginAirportSeqID', 'OriginCityMarketID', 'OriginCityName',
#        'OriginState', 'OriginStateFips', 'OriginStateName', 'OriginWac',
#        'DestAirportID', 'DestAirportSeqID', 'DestCityMarketID', 'DestCityName',
#        'DestState', 'DestStateFips', 'DestStateName', 'DestWac', 'DepDel15',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4078318 entries, 0 to 590541
# Data columns (total 61 columns):
#  #   Column                                   Dtype
# ---  ------                                   -----
#  0   FlightDate                               datetime64[us]
#  1   Airline                                  object
#  2   Origin                                   object
#  3   Dest                                     object
#  4   Cancelled                                bool
#  5   Diverted                                 bool
#  6   CRSDepTime                               int64
#  7   DepTime                                  float64
#  8   DepDelayMinutes                          float64
#  9   DepDelay                                 float64
#  10  ArrTime                                  float64
#  11  ArrDelayMinutes                          float64
#  12  AirTime                                  float64
# ...

# %%
df.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4078318 entries, 0 to 590541
# Columns: 61 entries, FlightDate to DivAirportLandings
# dtypes: bool(2), datetime64[us](1), float64(18), int64(23), object(17)
# memory usage: 1.8+ GB

# %%
df.describe()
# Out:
#                        FlightDate    CRSDepTime       DepTime  \
# count                     4078318  4.078318e+06  3.957885e+06
# mean   2022-04-18 12:10:43.903101  1.329587e+03  1.334374e+03
# min           2022-01-01 00:00:00  1.000000e+00  1.000000e+00
# 25%           2022-02-25 00:00:00  9.140000e+02  9.170000e+02
# 50%           2022-04-19 00:00:00  1.320000e+03  1.325000e+03
# 75%           2022-06-11 00:00:00  1.735000e+03  1.744000e+03
# max           2022-07-31 00:00:00  2.359000e+03  2.400000e+03
# std                           NaN  4.904801e+02  5.056219e+02
#
#        DepDelayMinutes      DepDelay       ArrTime  ArrDelayMinutes  \
# count     3.957823e+06  3.957823e+06  3.954079e+06     3.944916e+06
# mean      1.601494e+01  1.309049e+01  1.457886e+03     1.578307e+01
# min       0.000000e+00 -7.800000e+01  1.000000e+00     0.000000e+00
# 25%       0.000000e+00 -5.000000e+00  1.046000e+03     0.000000e+00
# ...

# %%
pd.set_option("display.float_format", lambda x: "%.2f" % x)
df.describe()
# Out:
#                        FlightDate  CRSDepTime    DepTime  DepDelayMinutes  \
# count                     4078318  4078318.00 3957885.00       3957823.00
# mean   2022-04-18 12:10:43.903101     1329.59    1334.37            16.01
# min           2022-01-01 00:00:00        1.00       1.00             0.00
# 25%           2022-02-25 00:00:00      914.00     917.00             0.00
# 50%           2022-04-19 00:00:00     1320.00    1325.00             0.00
# 75%           2022-06-11 00:00:00     1735.00    1744.00            11.00
# max           2022-07-31 00:00:00     2359.00    2400.00          7223.00
# std                           NaN      490.48     505.62            52.31
#
#         DepDelay    ArrTime  ArrDelayMinutes    AirTime  CRSElapsedTime  \
# count 3957823.00 3954079.00       3944916.00 3944916.00      4078318.00
# mean       13.09    1457.89            15.78     111.01          141.32
# min       -78.00       1.00             0.00       8.00          -48.00
# ...
